# %%
import torch
import DreamingNets
import matplotlib.pyplot as plt
import numpy as np
import hockey.hockey_env as h_env
import gymnasium as gym
import config

# %matplotlib inline

# %%
RNET = DreamingNets.reward_net()

# %%
env = h_env.HockeyEnv()

# %%
o, info = env.reset()
player1 = h_env.BasicOpponent(weak=True)
player2 = h_env.BasicOpponent(weak=True)

# %%
def cut_data(data):
    to_remove = []
    for i in range(len(data)):
        if data[i][1] < 1 and data[i][1] > -1 and np.random.rand() < 0.5:
            to_remove.append(i)
    for i in reversed(to_remove):
        data.pop(i)
    return data

# %%
def densify_rewards(data):
    count = 0
    for j in range(len(data)): 
        if data[j][1] > 5 or data[j][1] < -5:
            for i in range(1, 10):
                data[j - i] = (data[j-1][0], data[j-1][1] * 0.5 + data[j][1] * 0.5)
            count += 1
    return data

# %%
def run_episode():
    obs_buffer = []
    reward_buffer=[]
    for _ in range(config.TRAIN_SEQUENCES):
        obs, info = env.reset()
        obs_agent2 = env.obs_agent_two()
        for _ in range(config.TRAIN_STEPS):
            a1 = player1.act(obs)
            a2 = player2.act(obs_agent2)
            obs, r, d, t, info = env.step(np.hstack([a1,a2]))    
            obs_buffer.append(obs)
            reward_buffer.append(r)
            obs_agent2 = env.obs_agent_two()
            if d or t: break
    obs_buffer = np.asarray(obs_buffer)
    reward_buffer = np.asarray(reward_buffer)
    batch = [(obs, reward) for obs, reward in zip(obs_buffer, reward_buffer)]
    #print(len(batch))
    batch = densify_rewards(batch)
    batch = cut_data(batch)
    #print(len(batch))
    RNET.train_episode(batch)

# %%
def test_run():
    obs_buffer = []
    reward_buffer=[]
    obs, info = env.reset()
    obs_agent2 = env.obs_agent_two()
    for _ in range(config.TRAIN_STEPS):
        a1 = player1.act(obs)
        a2 = player2.act(obs_agent2)
        obs, r, d, t, info = env.step(np.hstack([a1,a2]))    
        obs_buffer.append(obs)
        reward_buffer.append(r)
        obs_agent2 = env.obs_agent_two()
        if d or t: break
    obs_buffer = np.asarray(obs_buffer)
    reward_buffer = np.asarray(reward_buffer)
    for i in range(obs_buffer.shape[0]):
        print("Expected result ", reward_buffer[i], "Prediciton " , RNET.predict(obs_buffer[i]))

# %%
#env.close()

# %%
for e in range(200):
    print("Epoch  ", e)
    run_episode()
# Out:
# Epoch   0
# 11215
# 5693
# RNET Validation loss:  0.5514425881693956
# Epoch   1
# 10544
# 5447
# RNET Validation loss:  0.45234290549039097
# Epoch   2
# 12618
# 6492
# RNET Validation loss:  0.435703523241929
# Epoch   3
# 13131
# 6595
# RNET Validation loss:  0.43940833970615445
# Epoch   4
# 12827
# 6533
# RNET Validation loss:  0.4658886717892836
# Epoch   5
# 11817
# 6024
# RNET Validation loss:  0.4756178184467599
# Epoch   6
# 12225
# 6374
# RNET Validation loss:  0.4957582495421124
# Epoch   7
# 11924
# 6101
# RNET Validation loss:  0.7840765631104116
# Epoch   8
# 12593
# 6291
# RNET Validation loss:  0.522057706442193
# Epoch   9
# 12246
# 6330
# RNET Validation loss:  0.42232789028198936
# Epoch   10
# 12208
# 6264
# RNET Validation loss:  0.3364595840310363
# Epoch   11
# 12485
# 6379
# RNET Validation loss:  0.3700274477891651
# Epoch   12
# 11852
# 6028
# RNET Validation loss:  0.28749912738358957
# Epoch   13
# 12327
# 6281
# RNET Validation loss:  0.21187660405873715
# Epoch   14
# 12739
# 6436
# RNET Validation loss:  0.22951595943929554
# Epoch   15
# 12964
# 6600
# RNET Validation loss:  0.3590584528776002
# Epoch   16
# 12236
# 6206
# RNET Validation loss:  0.40968288223521304
# Epoch   17
# 12172
# 6223
# RNET Validation loss:  0.6199205837955738
# Epoch   18
# 12446
# 6356
# RNET Validation loss:  0.2663102087705163
# Epoch   19
# 12644
# 6421
# RNET Validation loss:  0.33883657671813805
# Epoch   20
# 11763
# 5989
# RNET Validation loss:  0.4200918189956746
# Epoch   21
# 11550
# 5972
# RNET Validation loss:  0.4164752517893248
# Epoch   22
# 12770
# 6460
# RNET Validation loss:  0.2958996353609011
# Epoch   23
# 12595
# 6491
# RNET Validation loss:  0.33719717397880855
# Epoch   24
# 11232
# 5649
# RNET Validation loss:  0.33307688306348754
# Epoch   25
# 11063
# 5712
# RNET Validation loss:  0.35974020939897877
# Epoch   26
# 12669
# 6439
# RNET Validation loss:  0.20868695032539147
# Epoch   27
# 11822
# 6138
# RNET Validation loss:  0.5195674357368876
# Epoch   28
# 12417
# 6335
# RNET Validation loss:  0.4322831124616556
# Epoch   29
# 12166
# 6150
# RNET Validation loss:  0.25807527477524095
# Epoch   30
# 12277
# 6397
# RNET Validation loss:  0.27005472353773347
# Epoch   31
# 12508
# 6277
# RNET Validation loss:  0.3385117201087373
# Epoch   32
# 11592
# 5978
# RNET Validation loss:  0.28991161249244596
# Epoch   33
# 12314
# 6295
# RNET Validation loss:  0.4106946060607403
# Epoch   34
# 11407
# 5895
# RNET Validation loss:  0.7330884056108644
# Epoch   35
# 12919
# 6539
# RNET Validation loss:  0.29065669519213644
# Epoch   36
# 12312
# 6254
# RNET Validation loss:  0.565312735587052
# Epoch   37
# 11449
# 5787
# RNET Validation loss:  0.4774642472267167
# Epoch   38
# 12355
# 6306
# RNET Validation loss:  0.3518057726605651
# Epoch   39
# 12699
# 6499
# RNET Validation loss:  0.4427443050848783
# Epoch   40
# 11498
# 5835
# RNET Validation loss:  0.802503704032315
# Epoch   41
# 13178
# 6736
# RNET Validation loss:  0.21031610526603856
# Epoch   42
# 12447
# 6292
# RNET Validation loss:  0.7109577993265093
# Epoch   43
# 11732
# 6006
# RNET Validation loss:  0.2611631664057032
# Epoch   44
# 12119
# 6235
# RNET Validation loss:  0.25068271957015
# Epoch   45
# 12957
# 6644
# RNET Validation loss:  0.2609073054945074
# Epoch   46
# 11271
# 5856
# RNET Validation loss:  0.29872530347941134
# Epoch   47
# 11559
# 5815
# RNET Validation loss:  0.5060010274848344
# Epoch   48
# 12288
# 6188
# RNET Validation loss:  0.32343894371746984
# Epoch   49
# 12584
# 6463
# RNET Validation loss:  0.39564626561526667
# Epoch   50
# 11808
# 6085
# RNET Validation loss:  0.39711948987329027
# Epoch   51
# 12102
# 6197
# RNET Validation loss:  1.0013430558718497
# Epoch   52
# 13785
# 6924
# RNET Validation loss:  0.3121739715061978
# Epoch   53
# 12722
# 6417
# RNET Validation loss:  0.3620005025177383
# Epoch   54
# 12859
# 6560
# RNET Validation loss:  0.1940724799301927
# Epoch   55
# 11741
# 5960
# RNET Validation loss:  0.21354208682259332
# Epoch   56
# 11651
# 5976
# RNET Validation loss:  0.474569588698235
# Epoch   57
# 11593
# 5981
# RNET Validation loss:  0.43105834920903724
# Epoch   58
# 11575
# 5952
# RNET Validation loss:  0.2595844066624882
# Epoch   59
# 12714
# 6455
# RNET Validation loss:  0.25674136855252294
# Epoch   60
# 11877
# 6089
# RNET Validation loss:  0.37439133141855113
# Epoch   61
# 12382
# 6315
# RNET Validation loss:  0.2914482283207128
# Epoch   62
# 11239
# 5872
# RNET Validation loss:  0.3932856519243218
# Epoch   63
# 12040
# 6066
# RNET Validation loss:  1.4954813458632816
# Epoch   64
# 11604
# 5933
# RNET Validation loss:  0.3924912185019934
# Epoch   65
# 11297
# 5796
# RNET Validation loss:  0.419715204360544
# Epoch   66
# 13587
# 6937
# RNET Validation loss:  0.39959106525620464
# Epoch   67
# 11791
# 6064
# RNET Validation loss:  0.35045737773645175
# Epoch   68
# 12429
# 6279
# RNET Validation loss:  0.5572018125060164
# Epoch   69
# 12285
# 6317
# RNET Validation loss:  0.39304859275436016
# Epoch   70
# 12144
# 6190
# RNET Validation loss:  0.3019958044406291
# Epoch   71
# 11051
# 5748
# RNET Validation loss:  0.26190311811115785
# Epoch   72
# 11796
# 6043
# RNET Validation loss:  0.3059167613276368
# Epoch   73
# 13031
# 6673
# RNET Validation loss:  0.19774209188744654
# Epoch   74
# 12745
# 6549
# RNET Validation loss:  0.5419379276236941
# Epoch   75
# 11414
# 5858
# RNET Validation loss:  0.2984977527576475
# Epoch   76
# 12448
# 6262
# RNET Validation loss:  0.2039213420217869
# Epoch   77
# 12204
# 6196
# RNET Validation loss:  0.3103379264031502
# Epoch   78
# 12935
# 6593
# RNET Validation loss:  0.44303825222501286
# Epoch   79
# 11045
# 5607
# RNET Validation loss:  0.3598557532887081
# Epoch   80
# 12128
# 6144
# RNET Validation loss:  0.3069326232907688
# Epoch   81
# 12211
# 6150
# RNET Validation loss:  0.40327326317010515
# Epoch   82
# 12754
# 6461
# RNET Validation loss:  0.4626954579070781
# Epoch   83
# 11592
# 5935
# RNET Validation loss:  0.21701383098429622
# Epoch   84
# 13906
# 7028
# RNET Validation loss:  0.2780764657111549
# Epoch   85
# 12706
# 6445
# RNET Validation loss:  0.34435511795589385
# Epoch   86
# 11995
# 6207
# RNET Validation loss:  0.3365095425551982
# Epoch   87
# 11987
# 6127
# RNET Validation loss:  0.2671105661376431
# Epoch   88
# 12399
# 6281
# RNET Validation loss:  0.5439098966391795
# Epoch   89
# 11857
# 6102
# RNET Validation loss:  0.44443887432923573
# Epoch   90
# 12051
# 6152
# RNET Validation loss:  0.25290984317845133
# Epoch   91
# 11741
# 6040
# RNET Validation loss:  0.33067330895480973
# Epoch   92
# 12937
# 6619
# RNET Validation loss:  0.2942511006503664
# Epoch   93
# 12026
# 6097
# RNET Validation loss:  0.37195457552290345
# Epoch   94
# 11836
# 6122
# RNET Validation loss:  0.2398674586411063
# Epoch   95
# 11595
# 5957
# RNET Validation loss:  0.48328480231848425
# Epoch   96
# 12461
# 6390
# RNET Validation loss:  0.14752796098461812
# Epoch   97
# 12522
# 6325
# RNET Validation loss:  0.27997837157825817
# Epoch   98
# 12512
# 6285
# RNET Validation loss:  0.1958786909436653
# Epoch   99
# 11495
# 6039
# RNET Validation loss:  0.5117919367829696
# Epoch   100
# 12712
# 6544
# RNET Validation loss:  0.2680755358985315
# Epoch   101
# 12745
# 6524
# RNET Validation loss:  0.4479960283728887
# Epoch   102
# 13022
# 6570
# RNET Validation loss:  0.45451522648888165
# Epoch   103
# 12745
# 6523
# RNET Validation loss:  0.33944902068092264
# Epoch   104
# 12510
# 6306
# RNET Validation loss:  0.12262550930902302
# Epoch   105
# 13002
# 6611
# RNET Validation loss:  0.20445626539530512
# Epoch   106
# 13128
# 6521
# RNET Validation loss:  0.36209439078049843
# Epoch   107
# 11115
# 5824
# RNET Validation loss:  0.44445999317506807
# Epoch   108
# 12470
# 6357
# RNET Validation loss:  0.2676751347386539
# Epoch   109
# 12368
# 6343
# RNET Validation loss:  0.44580119512175825
# Epoch   110
# 12654
# 6510
# RNET Validation loss:  0.17292524901971953
# Epoch   111
# 13345
# 6670
# RNET Validation loss:  0.2718649237478819
# Epoch   112
# 11663
# 5919
# RNET Validation loss:  0.33004204112090985
# Epoch   113
# 11218
# 5808
# RNET Validation loss:  0.5450159202655129
# Epoch   114
# 12022
# 6222
# RNET Validation loss:  0.2036798988965454
# Epoch   115
# 12477
# 6382
# RNET Validation loss:  0.25728423028671493
# Epoch   116
# 12121
# 6223
# RNET Validation loss:  0.2001575624991068
# Epoch   117
# 12417
# 6301
# RNET Validation loss:  0.21044390119254142
# Epoch   118
# 12324
# 6192
# RNET Validation loss:  0.31560130382668794
# Epoch   119
# 11052
# 5661
# RNET Validation loss:  0.6667135233396004
# Epoch   120
# 11031
# 5688
# RNET Validation loss:  0.4356381869714324
# Epoch   121
# 11494
# 5954
# RNET Validation loss:  0.2785269927247762
# Epoch   122
# 11058
# 5781
# RNET Validation loss:  0.282167127305385
# Epoch   123
# 12568
# 6473
# RNET Validation loss:  0.18943696288655634
# Epoch   124
# 12041
# 6092
# RNET Validation loss:  0.3203577776832071
# Epoch   125
# 12568
# 6376
# RNET Validation loss:  0.2193440684087015
# Epoch   126
# 11662
# 5975
# RNET Validation loss:  0.4972229548819606
# Epoch   127
# 11715
# 6059
# RNET Validation loss:  0.4700996441625232
# Epoch   128
# 12428
# 6319
# RNET Validation loss:  0.32192067224352994
# Epoch   129
# 11848
# 5991
# RNET Validation loss:  0.47346790827880453
# Epoch   130
# 12641
# 6471
# RNET Validation loss:  0.23798248934430127
# Epoch   131
# 11533
# 5925
# RNET Validation loss:  0.22282221622614432
# Epoch   132
# 12329
# 6333
# RNET Validation loss:  0.5293182311035932
# Epoch   133
# 12148
# 6148
# RNET Validation loss:  0.47184974840009886
# Epoch   134
# 11256
# 5755
# RNET Validation loss:  0.298111150938918
# Epoch   135
# 12395
# 6288
# RNET Validation loss:  0.27155052861383405
# Epoch   136
# 11686
# 5920
# RNET Validation loss:  0.3021793459866027
# Epoch   137
# 12032
# 6161
# RNET Validation loss:  0.23549346923888642
# Epoch   138
# 11263
# 5776
# RNET Validation loss:  0.37031140488113895
# Epoch   139
# 12888
# 6569
# RNET Validation loss:  0.17951005330301592
# Epoch   140
# 11570
# 5936
# RNET Validation loss:  0.38131129941639796
# Epoch   141
# 13164
# 6723
# RNET Validation loss:  0.45203903314818505
# Epoch   142
# 12138
# 6156
# RNET Validation loss:  0.30324583877265054
# Epoch   143
# 12158
# 6174
# RNET Validation loss:  0.41877566032711394
# Epoch   144
# 12105
# 6229
# RNET Validation loss:  0.2180150738651876
# Epoch   145
# 11878
# 6097
# RNET Validation loss:  0.2741131646739967
# Epoch   146
# 11933
# 6069
# RNET Validation loss:  0.5466451805037537
# Epoch   147
# 11807
# 6068
# RNET Validation loss:  0.3493835327801879
# Epoch   148
# 13154
# 6699
# RNET Validation loss:  0.2515567410473973
# Epoch   149
# 12910
# 6605
# RNET Validation loss:  0.2276626623883208
# Epoch   150
# 12860
# 6581
# RNET Validation loss:  0.2539887198933403
# Epoch   151
# 12675
# 6430
# RNET Validation loss:  0.41626408745104426
# Epoch   152
# 11873
# 6034
# RNET Validation loss:  0.28242435474381766
# Epoch   153
# 11118
# 5818
# RNET Validation loss:  0.28430579739457107
# Epoch   154
# 11731
# 6144
# RNET Validation loss:  0.3208740420076756
# Epoch   155
# 11500
# 5798
# RNET Validation loss:  0.18317673922119107
# Epoch   156
# 12517
# 6300
# RNET Validation loss:  0.238343603288473
# Epoch   157
# 9917
# 5128
# RNET Validation loss:  0.3464362865642329
# Epoch   158
# 12972
# 6548
# RNET Validation loss:  0.2103491607772549
# Epoch   159
# 12172
# 6286
# RNET Validation loss:  0.28744575812646006
# Epoch   160
# 13265
# 6727
# RNET Validation loss:  0.22638818737169744
# Epoch   161
# 11735
# 5977
# RNET Validation loss:  0.22890418315439323
# Epoch   162
# 13574
# 6825
# RNET Validation loss:  0.12036395029854674
# Epoch   163
# 11638
# 6015
# RNET Validation loss:  0.5463059499899798
# Epoch   164
# 12999
# 6600
# RNET Validation loss:  0.25248307890073907
# Epoch   165
# 12043
# 6092
# RNET Validation loss:  0.3607432825869602
# Epoch   166
# 11488
# 5795
# RNET Validation loss:  0.4710793605964528
# Epoch   167
# 11086
# 5578
# RNET Validation loss:  0.7481963891012766
# Epoch   168
# 12455
# 6321
# RNET Validation loss:  0.19595301943559712
# Epoch   169
# 12752
# 6500
# RNET Validation loss:  0.28337646309298997
# Epoch   170
# 13246
# 6785
# RNET Validation loss:  0.20637710185142494
# Epoch   171
# 11788
# 6053
# RNET Validation loss:  0.5090794923011084
# Epoch   172
# 14048
# 6995
# RNET Validation loss:  0.291813741446589
# Epoch   173
# 12069
# 6230
# RNET Validation loss:  0.2847446091310788
# Epoch   174
# 13458
# 6844
# RNET Validation loss:  0.22505644190443044
# Epoch   175
# 11894
# 6069
# RNET Validation loss:  0.42601115262355005
# Epoch   176
# 11741
# 5978
# RNET Validation loss:  0.4731410440104217
# Epoch   177
# 12556
# 6326
# RNET Validation loss:  0.33940214958515286
# Epoch   178
# 11254
# 5836
# RNET Validation loss:  0.3738010952925223
# Epoch   179
# 10819
# 5599
# RNET Validation loss:  0.3161272979621778
# Epoch   180
# 12056
# 6255
# RNET Validation loss:  0.13738941471070987
# Epoch   181
# 12016
# 6158
# RNET Validation loss:  0.42018102747947905
# Epoch   182
# 11909
# 6143
# RNET Validation loss:  0.320579785376452
# Epoch   183
# 12153
# 6193
# RNET Validation loss:  0.12460212842396005
# Epoch   184
# 11439
# 5876
# RNET Validation loss:  0.4084192672412462
# Epoch   185
# 12090
# 6191
# RNET Validation loss:  0.49973053244766297
# Epoch   186
# 11999
# 6113
# RNET Validation loss:  0.1940262351917227
# Epoch   187
# 12891
# 6546
# RNET Validation loss:  0.2727652274037085
# Epoch   188
# 12329
# 6293
# RNET Validation loss:  0.48718548196460404
# Epoch   189
# 13075
# 6716
# RNET Validation loss:  0.19868298979403093
# Epoch   190
# 12583
# 6365
# RNET Validation loss:  0.2209959618069996
# Epoch   191
# 12491
# 6355
# RNET Validation loss:  0.20339442686003914
# Epoch   192
# 12898
# 6589
# RNET Validation loss:  0.35457829426596194
# Epoch   193
# 12399
# 6322
# RNET Validation loss:  0.5168825732843705
# Epoch   194
# 12182
# 6217
# RNET Validation loss:  0.33673219186300124
# Epoch   195
# 10846
# 5574
# RNET Validation loss:  0.2602289797408582
# Epoch   196
# 12665
# 6479
# RNET Validation loss:  0.35392590059846313
# Epoch   197
# 12175
# 6190
# RNET Validation loss:  0.19816435003231578
# Epoch   198
# 11499
# 5908
# RNET Validation loss:  0.2575129968128667
# Epoch   199
# 12454
# 6300
# RNET Validation loss:  0.43049468079850794

# %%
test_run()
# Out:
# Expected result  -0.07272180438944181 Prediciton  -0.05637522041797638
# Expected result  -0.06983958716740218 Prediciton  -0.05261506140232086
# Expected result  -0.06580087452743087 Prediciton  -0.05059942603111267
# Expected result  -0.060805165433238106 Prediciton  -0.04669293761253357
# Expected result  -0.055052322182679934 Prediciton  -0.044605761766433716
# Expected result  -0.048742001196187414 Prediciton  -0.041895076632499695
# Expected result  -0.04211471018388952 Prediciton  -0.03859470784664154
# Expected result  -0.035349845991578394 Prediciton  -0.037399739027023315
# Expected result  -0.02868208550003534 Prediciton  -0.020895421504974365
# Expected result  -0.02473975438895847 Prediciton  -0.03718556463718414
# Expected result  -0.020830850581192224 Prediciton  -0.034801751375198364
# Expected result  0.0 Prediciton  -0.025088131427764893
# Expected result  0.0 Prediciton  -0.024539023637771606
# Expected result  0.0 Prediciton  -0.01717446744441986
# Expected result  0.0 Prediciton  -0.01384378969669342
# Expected result  -0.018110906603297432 Prediciton  -0.01444844901561737
# Expected result  -0.018110958558022396 Prediciton  -0.007735922932624817
# Expected result  0.0 Prediciton  -0.0050137341022491455
# Expected result  0.0 Prediciton  -0.00014093518257141113
# Expected result  0.0 Prediciton  0.004083111882209778
# Expected result  -0.018152117835577495 Prediciton  0.0012125968933105469
# Expected result  0.0 Prediciton  -0.005676984786987305
# Expected result  0.0 Prediciton  -0.02119624614715576
# Expected result  0.0 Prediciton  -0.02144782245159149
# Expected result  0.0 Prediciton  -0.025610893964767456
# Expected result  0.0 Prediciton  -0.023785173892974854
# Expected result  0.0 Prediciton  0.24047505855560303
# Expected result  0.0 Prediciton  2.476422071456909
# Expected result  0.0 Prediciton  4.844150543212891
# Expected result  0.0 Prediciton  7.0735273361206055
# Expected result  0.0 Prediciton  1.591285228729248
# Expected result  0.0 Prediciton  -0.005824938416481018
# Expected result  0.0 Prediciton  -0.000785142183303833
# Expected result  0.0 Prediciton  0.005067318677902222
# Expected result  0.0 Prediciton  0.009116962552070618
# Expected result  0.0 Prediciton  -0.0056162029504776
# Expected result  0.0 Prediciton  -0.03904937207698822
# Expected result  0.0 Prediciton  -0.0624881386756897
# Expected result  -0.22018125540221548 Prediciton  -0.0779089629650116
# Expected result  -0.20135325550857866 Prediciton  -0.10915198922157288
# Expected result  -0.18392307798602578 Prediciton  -0.13134214282035828
# Expected result  -0.16812360816428515 Prediciton  -0.1373448371887207
# Expected result  -0.1544809519244741 Prediciton  -0.13355597853660583
# Expected result  -0.14354057871982126 Prediciton  -0.12084782123565674
# Expected result  -0.13570647136835176 Prediciton  -0.1080525815486908
# Expected result  -0.13167982417792104 Prediciton  -0.10394081473350525
# Expected result  -0.1317885085595623 Prediciton  -0.6789755821228027
# Expected result  0.0 Prediciton  0.022422663867473602
# Expected result  0.0 Prediciton  0.01034390926361084
# Expected result  0.0 Prediciton  0.0019256770610809326
# Expected result  0.0 Prediciton  -0.00913284718990326
# Expected result  0.0 Prediciton  -0.023922964930534363
# Expected result  0.0 Prediciton  -0.03343425691127777
# Expected result  0.0 Prediciton  -0.02722322940826416
# Expected result  0.0 Prediciton  -0.008629664778709412
# Expected result  0.0 Prediciton  0.0023825913667678833
# Expected result  0.0 Prediciton  -0.001070454716682434
# Expected result  0.0 Prediciton  -0.005476698279380798
# Expected result  0.0 Prediciton  -0.0085543692111969
# Expected result  0.0 Prediciton  -0.012852072715759277
# Expected result  0.0 Prediciton  -0.016923874616622925
# Expected result  0.0 Prediciton  -0.021251991391181946
# Expected result  0.0 Prediciton  -0.025557398796081543
# Expected result  0.0 Prediciton  -0.029892608523368835
# Expected result  0.0 Prediciton  -0.03418499231338501
# Expected result  0.0 Prediciton  -0.03840109705924988
# Expected result  0.0 Prediciton  -0.010191723704338074
# Expected result  0.0 Prediciton  -0.008897960186004639
# Expected result  0.0 Prediciton  -0.005443647503852844
# Expected result  0.0 Prediciton  -0.0008417069911956787
# Expected result  0.0 Prediciton  -0.0007087141275405884
# Expected result  0.0 Prediciton  -0.019195616245269775
# Expected result  0.0 Prediciton  -0.0343581885099411
# Expected result  0.0 Prediciton  -0.051908940076828
# Expected result  0.0 Prediciton  -0.06914573907852173
# Expected result  0.0 Prediciton  -0.08407621085643768
# Expected result  -0.19857602776777328 Prediciton  -0.10179932415485382
# Expected result  -0.17784430023051614 Prediciton  -0.11910015344619751
# Expected result  -0.15723108496268026 Prediciton  -0.13362792134284973
# Expected result  -0.13694684293138104 Prediciton  -0.1371856927871704
# Expected result  -0.11707658557219264 Prediciton  -0.125535249710083
# Expected result  -0.09787941919406715 Prediciton  -0.11984309554100037
# Expected result  -0.07994759651396832 Prediciton  -0.1063845306634903
# Expected result  -0.064207442347178 Prediciton  -0.10093292593955994
# Expected result  -0.052767672952142686 Prediciton  -0.08882257342338562
# Expected result  -0.04879719914690949 Prediciton  -1.0554755926132202
# Expected result  0.0 Prediciton  0.0014640241861343384
# Expected result  0.0 Prediciton  -0.010577529668807983
# Expected result  0.0 Prediciton  -0.017682522535324097
# Expected result  0.0 Prediciton  -0.028436824679374695
# Expected result  0.0 Prediciton  -0.035815492272377014
# Expected result  0.0 Prediciton  -0.044757455587387085
# Expected result  0.0 Prediciton  -0.047052085399627686
# Expected result  0.0 Prediciton  -0.02950918674468994
# Expected result  0.0 Prediciton  -0.012081429362297058
# Expected result  0.0 Prediciton  -0.005837693810462952
# Expected result  0.0 Prediciton  -0.009677395224571228
# Expected result  0.0 Prediciton  -0.01412181556224823
# Expected result  0.0 Prediciton  -0.01573680341243744
# Expected result  0.0 Prediciton  -0.019890889525413513
# Expected result  0.0 Prediciton  -0.025068476796150208
# Expected result  0.0 Prediciton  -0.02583770453929901
# Expected result  0.0 Prediciton  -0.030127570033073425
# Expected result  0.0 Prediciton  -0.035956427454948425
# Expected result  0.0 Prediciton  -0.03639446198940277
# Expected result  0.0 Prediciton  -0.041287824511528015
# Expected result  0.0 Prediciton  -0.047937363386154175
# Expected result  0.0 Prediciton  -0.024139508605003357
# Expected result  0.0 Prediciton  -0.02398158609867096
# Expected result  0.0 Prediciton  -0.022610172629356384
# Expected result  0.0 Prediciton  -0.016054749488830566
# Expected result  0.0 Prediciton  -0.014767289161682129
# Expected result  0.0 Prediciton  -0.014318540692329407
# Expected result  0.0 Prediciton  -0.006352737545967102
# Expected result  0.0 Prediciton  -0.018232569098472595
# Expected result  0.0 Prediciton  -0.03413742780685425
# Expected result  0.0 Prediciton  -0.05052588880062103
# Expected result  0.0 Prediciton  -0.06620198488235474
# Expected result  0.0 Prediciton  -0.08207109570503235
# Expected result  -0.19502935560794493 Prediciton  -0.09762716293334961
# Expected result  -0.1772631677065791 Prediciton  -0.11322176456451416
# Expected result  -0.15956729890040555 Prediciton  -0.1288411021232605
# Expected result  -0.14205339055775856 Prediciton  -0.14048179984092712
# Expected result  -0.12479322890993089 Prediciton  -0.134313702583313
# Expected result  -0.10782235793886503 Prediciton  -0.1266821324825287
# Expected result  -0.09139292202933179 Prediciton  -0.12135112285614014
# Expected result  -0.07580622954827526 Prediciton  -0.11709660291671753
# Expected result  -0.061729313229048746 Prediciton  -0.10677525401115417
# Expected result  -0.05043554306711316 Prediciton  -0.10279642045497894
# Expected result  -0.04410211213842021 Prediciton  -0.09906624257564545
# Expected result  0.0 Prediciton  -0.0008166581392288208
# Expected result  0.0 Prediciton  -0.012764111161231995
# Expected result  0.0 Prediciton  -0.02334439754486084
# Expected result  0.0 Prediciton  -0.026923954486846924
# Expected result  0.0 Prediciton  -0.03757894039154053
# Expected result  0.0 Prediciton  -0.048994988203048706
# Expected result  0.0 Prediciton  -0.052237823605537415
# Expected result  0.0 Prediciton  -0.0613216757774353
# Expected result  0.0 Prediciton  -0.05191442370414734
# Expected result  0.0 Prediciton  -0.03618250787258148
# Expected result  0.0 Prediciton  -0.021901950240135193
# Expected result  0.0 Prediciton  -0.007023975253105164
# Expected result  0.0 Prediciton  0.0018978416919708252
# Expected result  0.0 Prediciton  -0.00466686487197876
# Expected result  0.0 Prediciton  -0.005989924073219299
# Expected result  0.0 Prediciton  -0.006686285138130188
# Expected result  0.0 Prediciton  -0.013890832662582397
# Expected result  0.0 Prediciton  -0.014764860272407532
# Expected result  0.0 Prediciton  -0.01635688543319702
# Expected result  0.0 Prediciton  -0.022631824016571045
# Expected result  0.0 Prediciton  -0.024175047874450684
# Expected result  0.0 Prediciton  -0.0258445143699646
# Expected result  0.0 Prediciton  -0.03166241943836212
# Expected result  0.0 Prediciton  -0.033541545271873474
# Expected result  0.0 Prediciton  -0.03740224242210388
# Expected result  0.0 Prediciton  -0.02056761085987091
# Expected result  0.0 Prediciton  -0.019228368997573853
# Expected result  0.0 Prediciton  -0.016820073127746582
# Expected result  0.0 Prediciton  -0.013904407620429993
# Expected result  0.0 Prediciton  -0.012550845742225647
# Expected result  0.0 Prediciton  -0.009981364011764526
# Expected result  0.0 Prediciton  -0.007649421691894531
# Expected result  0.0 Prediciton  -0.007157087326049805
# Expected result  0.0 Prediciton  -0.009436637163162231
# Expected result  0.0 Prediciton  -0.022624477744102478
# Expected result  0.0 Prediciton  -0.03725573420524597
# Expected result  0.0 Prediciton  -0.050149112939834595
# Expected result  0.0 Prediciton  -0.06300738453865051
# Expected result  0.0 Prediciton  -0.07727088034152985
# Expected result  -0.19888996427927347 Prediciton  -0.08987030386924744
# Expected result  -0.18346811728198517 Prediciton  -0.10248732566833496
# Expected result  -0.16813809176129643 Prediciton  -0.11648908257484436
# Expected result  -0.15293308277433218 Prediciton  -0.12727224826812744
# Expected result  -0.13781786081114716 Prediciton  -0.12018242478370667
# Expected result  -0.12291319867250136 Prediciton  -0.118466317653656
# Expected result  -0.10830351325055315 Prediciton  -0.10959456861019135
# Expected result  -0.09399245980343296 Prediciton  -0.10772354900836945
# Expected result  -0.08028546664830705 Prediciton  -0.09954948723316193
# Expected result  -0.06743382724216715 Prediciton  -0.09642595052719116
# Expected result  -0.056140727017463386 Prediciton  -0.08909104764461517
# Expected result  -0.04738853030356095 Prediciton  -0.08532749116420746
# Expected result  -0.04288236661204619 Prediciton  -0.07855157554149628
# Expected result  0.0 Prediciton  -0.00024628639221191406
# Expected result  0.0 Prediciton  -0.007554218173027039
# Expected result  0.0 Prediciton  -0.016089007258415222
# Expected result  0.0 Prediciton  -0.02421458065509796
# Expected result  0.0 Prediciton  -0.033143579959869385
# Expected result  0.0 Prediciton  -0.041396141052246094
# Expected result  0.0 Prediciton  -0.04670247435569763
# Expected result  0.0 Prediciton  -0.05499868094921112
# Expected result  0.0 Prediciton  -0.06344388425350189
# Expected result  0.0 Prediciton  -0.05910041928291321
# Expected result  0.0 Prediciton  -0.04704718291759491
# Expected result  0.0 Prediciton  -0.03517448902130127
# Expected result  0.0 Prediciton  -0.022124066948890686
# Expected result  0.0 Prediciton  -0.010514378547668457
# Expected result  0.0 Prediciton  0.0010334402322769165
# Expected result  0.0 Prediciton  -0.0020119547843933105
# Expected result  0.0 Prediciton  -0.0034728795289993286
# Expected result  0.0 Prediciton  -0.004895493388175964
# Expected result  0.0 Prediciton  -0.009375542402267456
# Expected result  0.0 Prediciton  -0.010628357529640198
# Expected result  0.0 Prediciton  -0.011882513761520386
# Expected result  0.0 Prediciton  -0.017138957977294922
# Expected result  0.0 Prediciton  -0.018322423100471497
# Expected result  0.0 Prediciton  -0.019619926810264587
# Expected result  0.0 Prediciton  -0.025187507271766663
# Expected result  0.0 Prediciton  -0.02646559476852417
# Expected result  0.0 Prediciton  -0.026896893978118896
# Expected result  0.0 Prediciton  -0.03370945155620575
# Expected result  0.0 Prediciton  -0.03425045311450958
# Expected result  0.0 Prediciton  -0.03567664325237274
# Expected result  0.0 Prediciton  -0.020437687635421753
# Expected result  0.0 Prediciton  -0.018743440508842468
# Expected result  0.0 Prediciton  -0.018538683652877808
# Expected result  0.0 Prediciton  -0.015103593468666077
# Expected result  0.0 Prediciton  -0.014340028166770935
# Expected result  0.0 Prediciton  -0.011304676532745361
# Expected result  0.0 Prediciton  -0.010044828057289124
# Expected result  0.0 Prediciton  -0.007245078682899475
# Expected result  0.0 Prediciton  -0.005780622363090515
# Expected result  0.0 Prediciton  -0.011100158095359802
# Expected result  0.0 Prediciton  -0.022238194942474365
# Expected result  0.0 Prediciton  -0.03409475088119507
# Expected result  0.0 Prediciton  -0.044895753264427185
# Expected result  0.0 Prediciton  -0.05554710328578949
# Expected result  0.0 Prediciton  -0.06739203631877899
# Expected result  -0.2084433734227073 Prediciton  -0.07792012393474579
# Expected result  -0.19512470891216296 Prediciton  -0.0882127434015274
# Expected result  -0.1818468423118373 Prediciton  -0.10001455247402191
# Expected result  -0.16860401093074012 Prediciton  -0.11030074954032898
# Expected result  -0.15542918368764336 Prediciton  -0.11801612377166748
# Expected result  -0.142347326677224 Prediciton  -0.11812648177146912
# Expected result  -0.12933787849990563 Prediciton  -0.11142274737358093
# Expected result  -0.11648044959576295 Prediciton  -0.1027269959449768
# Expected result  -0.10383390084251035 Prediciton  -0.10261289775371552
# Expected result  -0.09138771213384933 Prediciton  -0.09686629474163055
# Expected result  -0.07934098113612974 Prediciton  -0.09360142052173615
# Expected result  -0.06789765238122586 Prediciton  -0.08602763712406158
# Expected result  -0.05723927431280046 Prediciton  -0.08539192378520966
# Expected result  -0.04808214257229936 Prediciton  -0.07873634994029999
# Expected result  -0.04140724340607728 Prediciton  -0.0751258134841919
# Expected result  -0.038280378215587836 Prediciton  -0.07177320122718811
# Expected result  0.0 Prediciton  -0.00447729229927063
# Expected result  0.0 Prediciton  -0.01143193244934082
# Expected result  0.0 Prediciton  -0.020273610949516296
# Expected result  0.0 Prediciton  -0.02844098210334778
# Expected result  0.0 Prediciton  -0.035639479756355286
# Expected result  0.0 Prediciton  -0.041776761412620544
# Expected result  0.0 Prediciton  -0.049057021737098694
# Expected result  0.0 Prediciton  -0.057829707860946655
